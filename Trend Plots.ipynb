# %% [markdown]
# # File Calling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
# %matplotlib notebook

# %%
pd.read_excel
# Out:
# <function pandas.io.excel._base.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)>

# %% [markdown]
# # PDF Calling

# %%
Cu7PSe6_PDF = pd.read_excel('Cu7PSe6 PDF 00-033-0482.xlsx',                          #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
CuRSe_PDF = pd.read_excel('Cu0.87Se PDF 01-089-2734.xlsx',                             #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
Cu2_xSe_PDF = pd.read_excel('Cu2-xSex PDF 00-006-0680.xlsx',             #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
Cu3PSe4_PDF = pd.read_excel('Cu3PSe4 PDF 04-006-8347.xlsx',  #excel file where data is located                                #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %% [markdown]
# ## Temperature

# %%
NN_01_53 = pd.read_excel('NN-01-53_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_53_1 = NN_01_53['y_exp']+9500

# %%
NN_01_69 = pd.read_excel('NN-01-69_2021-02-09.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_69 = NN_01_69['y_exp']

# %%
NN_01_71 = pd.read_excel('NN-01-71_2021-02-13.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_71 = 0.8*NN_01_71['y_exp']+4000

# %%
NN_01_73 = pd.read_excel('NN-01-73_2021-02-17.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)

y_exp_73 = NN_01_73['y_exp']+14000

# %%
fig = plt.figure(figsize=(6,5))
gs = gridspec.GridSpec(4, 1, height_ratios=[1,0.1,.1,0.1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes.
plt.xlim(20,60)
ylim = (0,30000)
legLoc='upper right' #legend location

ax1 = plt.subplot(gs[3])
x = Cu3PSe4_PDF['2q']
y = Cu3PSe4_PDF['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(10,1100)
ax1.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax1.set_yticklabels([])
ax1.vlines(x, [0], y, lw=1, color = 'Black', label = '')
ax1.spines['bottom'].set_visible(True)
ax1.spines['top'].set_visible(False)
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax2 = plt.subplot(gs[2])
x1 = Cu2_xSe_PDF['2q']
y1 = Cu2_xSe_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,110)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x1, [0], y1, lw=1, color = 'darkgreen', label = '')
ax2.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax3 = plt.subplot(gs[0])
x2 = NN_01_69['2q']
y2 = y_exp_69
ax3.set_xlim(24, 60)
ax3.set_ylim(ylim)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x2, y2, lw=1, color = 'goldenrod', label = '')
ax3.spines['bottom'].set_visible(False)
ax3.tick_params(direction = 'inout', top = True, bottom = False, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("Black")
    
plt.title('Cu$_3$P + 0.15M Se/ODE, 20 mins', fontsize = 12)
    
ax4 = plt.subplot(gs[0])
x3 = NN_01_71['2q']
y3 = y_exp_71
ax4.set_xlim(24, 60)
ax4.set_ylim(ylim)
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x3, y3, lw=1, color = 'darkorange', label = '')
ax4.spines['bottom'].set_visible(False)
ax4.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax5 = plt.subplot(gs[0])
x4 = NN_01_73['2q']
y4 = y_exp_73
ax5.set_xlim(24, 60)
ax5.set_ylim(ylim)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x4, y4, lw=1, color = 'darkred', label = '')
ax5.spines['bottom'].set_visible(False)
ax5.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax6 = plt.subplot(gs[0])
x5 = NN_01_53['2q']
y5 = y_exp_53_1
ax6.set_xlim(24, 60)
ax6.set_ylim(ylim)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.plot(x5, y5, lw=1, color = 'orangered', label = '')
ax6.spines['bottom'].set_visible(False)
ax6.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax7 = plt.subplot(gs[1])
x6 = Cu7PSe6_PDF['2q']
y6 = Cu7PSe6_PDF['Intensity']
ax7.set_xlim(24, 60)
ax7.set_ylim(6,15)
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x6, [0], y6, lw=1, color = 'royalblue', label = '')
ax7.spines['bottom'].set_visible(False)
ax7.spines['top'].set_visible(False)
ax7.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

fig.text(0.85, .85, '310$^o$C', ha='center', va='center', color = 'darkred', fontsize = 12)
fig.text(0.85, .81, '300$^o$C', ha='center', va='center', color = 'orangered', fontsize = 12)
fig.text(0.85, .77, '275$^o$C', ha='center', va='center', color = 'darkorange', fontsize = 12)
fig.text(0.85, .73, '250$^o$C', ha='center', va='center', color = 'goldenrod', fontsize = 12)


fig.text(0.952, .245, 'Cu$_7$PSe$_6$', ha='center', va='center', color = 'royalblue', fontsize = 10)
fig.text(0.952, .14, 'Cu$_3$PSe$_4$', ha='center', va='center', color = 'black', fontsize = 10)
fig.text(0.952, .192, 'Cu$_{2-x}$Se', ha='center', va='center', color = 'darkgreen', fontsize = 10)

fig.text(.5, 0.03, '$2\Theta$, Cu K$_{\\alpha}$ ($^\circ$)', ha='center', va='center',fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)

plt.savefig("Temperature_subplot.pdf", dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# # Concentration - Trapping

# %%
NN_01_53_1 = pd.read_excel('NN-01-53_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_53_1 = NN_01_53_1['y_exp']+4000

# %%
NN_01_48 = pd.read_excel('NN-01-48_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_48 = NN_01_48['y_exp']

# %%
NN_01_95 = pd.read_csv('NN-01-95_2021-04-14_fit.txt',
                 sep=",",
                 header=1,
                 names=["2q", "y_exp", "diff", "y_calc"])
y_exp_95 = 0.8*NN_01_95['y_exp']+8500

# %%
fig = plt.figure(figsize=(6,5))
gs = gridspec.GridSpec(4, 1, height_ratios=[1,0.1,.1,0.1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes.
plt.xlim(20,60)
ylim = (0,22500)
legLoc='upper right' #legend location

ax1 = plt.subplot(gs[3])
x = Cu3PSe4_PDF['2q']
y = Cu3PSe4_PDF['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(10,1100)
ax1.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax1.set_yticklabels([])
ax1.vlines(x, [0], y, lw=1, color = 'Black', label = '')
ax1.spines['bottom'].set_visible(True)
ax1.spines['top'].set_visible(False)
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax2 = plt.subplot(gs[2])
x1 = Cu2_xSe_PDF['2q']
y1 = Cu2_xSe_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,110)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x1, [0], y1, lw=1, color = 'darkgreen', label = '')
ax2.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax3 = plt.subplot(gs[0])
x2 = NN_01_48['2q']
y2 = y_exp_48
ax3.set_xlim(24, 60)
ax3.set_ylim(ylim)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x2, y2, lw=1, color = 'darkblue', label = '')
ax3.spines['bottom'].set_visible(False)
ax3.tick_params(direction = 'inout', top = True, bottom = False, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("Black")
    
plt.title('Cu$_3$P + 0.10M Se/ODE, trapping, 20 mins, X=Cu$_7$PSe$_6$', fontsize = 12)
    
ax4 = plt.subplot(gs[0])
x3 = NN_01_53['2q']
y3 = y_exp_53_1
ax4.set_xlim(24, 60)
ax4.set_ylim(ylim)
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x3, y3, lw=1, color = 'darkcyan', label = '')
ax4.spines['bottom'].set_visible(False)
ax4.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax5 = plt.subplot(gs[0])
x4 = NN_01_95['2q']
y4 = y_exp_95
ax5.set_xlim(24, 60)
ax5.set_ylim(ylim)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x4, y4, lw=1, color = 'darkmagenta', label = '')
ax5.spines['bottom'].set_visible(False)
ax5.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax6 = plt.subplot(gs[1])
x5 = Cu7PSe6_PDF['2q']
y5 = Cu7PSe6_PDF['Intensity']
ax6.set_xlim(24, 60)
ax6.set_ylim(6,15)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x5, [0], y5, lw=1, color = 'royalblue', label = '')
ax6.spines['bottom'].set_visible(False)
ax6.spines['top'].set_visible(False)
ax6.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

fig.text(0.815, .85, 'X=18.93%', ha='center', va='center', color = 'darkmagenta', fontsize = 12)
fig.text(0.835, .81, '53.65%', ha='center', va='center', color = 'darkcyan', fontsize = 12)
fig.text(0.835, .77, '75.58%', ha='center', va='center', color = 'darkblue', fontsize = 12)

fig.text(0.952, .245, 'Cu$_7$PSe$_6$', ha='center', va='center', color = 'royalblue', fontsize = 10)
fig.text(0.952, .14, 'Cu$_3$PSe$_4$', ha='center', va='center', color = 'black', fontsize = 10)
fig.text(0.952, .192, 'Cu$_{2-x}$Se', ha='center', va='center', color = 'darkgreen', fontsize = 10)

fig.text(.5, 0.03, '$2\Theta$, Cu K$_{\\alpha}$ ($^\circ$)', ha='center', va='center',fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)

plt.savefig("degradation subplot.pdf", dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# # Concentration - Purging

# %%
NN_01_43 = pd.read_excel('NN-01-43_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_43 = NN_01_43['y_exp']

# %%
NN_01_54 = pd.read_excel('NN-01-54_2021-02-17.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_54 = 0.8*NN_01_54['y_exp']+4500

# %%
NN_01_56 = pd.read_excel('NN-01-56_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_56 = NN_01_56['y_exp']+10000

# %%
fig = plt.figure(figsize=(6,5))
gs = gridspec.GridSpec(4, 1, height_ratios=[1,0.1,.1,0.1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes.
plt.xlim(20,60)
ylim = (0,22500)
legLoc='upper right' #legend location
t = 'darkmagenta'

ax1 = plt.subplot(gs[3])
x = Cu3PSe4_PDF['2q']
y = Cu3PSe4_PDF['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(10,1100)
ax1.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax1.set_yticklabels([])
ax1.vlines(x, [0], y, lw=1, color = 'Black', label = '')
ax1.spines['bottom'].set_visible(True)
ax1.spines['top'].set_visible(False)
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax2 = plt.subplot(gs[2])
x1 = Cu2_xSe_PDF['2q']
y1 = Cu2_xSe_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,110)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x1, [0], y1, lw=1, color = 'darkgreen', label = '')
ax2.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax3 = plt.subplot(gs[0])
x2 = NN_01_43['2q']
y2 = y_exp_43
ax3.set_xlim(24, 60)
ax3.set_ylim(ylim)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x2, y2, lw=1, color = 'darkblue', label = '')
ax3.spines['bottom'].set_visible(False)
ax3.tick_params(direction = 'inout', top = True, bottom = False, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("Black")
    
plt.title('Cu$_3$P + X Se/ODE, purging, 20 mins', fontsize = 12)
    
ax4 = plt.subplot(gs[0])
x3 = NN_01_54['2q']
y3 = y_exp_54
ax4.set_xlim(24, 60)
ax4.set_ylim(ylim)
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x3, y3, lw=1, color = 'darkcyan', label = '')
ax4.spines['bottom'].set_visible(False)
ax4.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax5 = plt.subplot(gs[0])
x4 = NN_01_56['2q']
y4 = y_exp_56
ax5.set_xlim(24, 60)
ax5.set_ylim(ylim)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x4, y4, lw=1, color = 'darkmagenta', label = '')
ax5.spines['bottom'].set_visible(False)
ax5.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax6 = plt.subplot(gs[1])
x5 = Cu7PSe6_PDF['2q']
y5 = Cu7PSe6_PDF['Intensity']
ax6.set_xlim(24, 60)
ax6.set_ylim(6,15)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x5, [0], y5, lw=1, color = 'royalblue', label = '')
ax6.spines['bottom'].set_visible(False)
ax6.spines['top'].set_visible(False)
ax6.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

fig.text(0.72, .85, 'X = 0.10M for 10 mins', ha='center', va='center', color = 'darkmagenta', fontsize = 12)
fig.text(0.835, .81, '0.10M', ha='center', va='center', color = 'darkcyan', fontsize = 12)
fig.text(0.835, .77, '0.05M', ha='center', va='center', color = 'darkblue', fontsize = 12)

fig.text(0.952, .245, 'Cu$_7$PSe$_6$', ha='center', va='center', color = 'royalblue', fontsize = 10)
fig.text(0.952, .14, 'Cu$_3$PSe$_4$', ha='center', va='center', color = 'black', fontsize = 10)
fig.text(0.952, .192, 'Cu$_{2-x}$Se', ha='center', va='center', color = 'darkgreen', fontsize = 10)

fig.text(.5, 0.03, '$2\Theta$, Cu K$_{\\alpha}$ ($^\circ$)', ha='center', va='center',fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)

plt.savefig("concentration_purging_subplot.pdf", dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:55: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# # Headspace

# %%
NN_01_43_1 = pd.read_excel('NN-01-43_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_43_1 = NN_01_43_1['y_exp']+6000

# %%
NN_01_41_1 = pd.read_excel('NN-01-41_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_41_1 = NN_01_41_1['y_exp']+3000

# %%
NN_01_39 = pd.read_excel('NN-01-39_2021-02-14.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_39 = NN_01_39['y_exp']

# %%
fig = plt.figure(figsize=(6,5))
gs = gridspec.GridSpec(4, 1, height_ratios=[1,0.1,.1,0.1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes.
plt.xlim(20,60)
ylim = (0,17500)
legLoc='upper right' #legend location

ax1 = plt.subplot(gs[3])
x = Cu3PSe4_PDF['2q']
y = Cu3PSe4_PDF['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(10,1100)
ax1.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax1.set_yticklabels([])
ax1.vlines(x, [0], y, lw=1, color = 'Black', label = '')
ax1.spines['bottom'].set_visible(True)
ax1.spines['top'].set_visible(False)
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax2 = plt.subplot(gs[2])
x1 = Cu2_xSe_PDF['2q']
y1 = Cu2_xSe_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,110)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x1, [0], y1, lw=1, color = 'darkgreen', label = '')
ax2.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax3 = plt.subplot(gs[0])
x2 = NN_01_39['2q']
y2 = y_exp_39
ax3.set_xlim(24, 60)
ax3.set_ylim(ylim)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x2, y2, lw=1, color = 'darkblue', label = '')
ax3.spines['bottom'].set_visible(False)
ax3.tick_params(direction = 'inout', top = True, bottom = False, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("Black")
    
plt.title('Cu$_3$P + 0.05M Se/ODE, 20 mins, f(headspace)', fontsize = 12)
    
ax4 = plt.subplot(gs[0])
x3 = NN_01_41['2q']
y3 = y_exp_41_1
ax4.set_xlim(24, 60)
ax4.set_ylim(ylim)
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x3, y3, lw=1, color = 'darkcyan', label = '')
ax4.spines['bottom'].set_visible(False)
ax4.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax5 = plt.subplot(gs[0])
x4 = NN_01_43['2q']
y4 = y_exp_43_1
ax5.set_xlim(24, 60)
ax5.set_ylim(ylim)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x4, y4, lw=1, color = 'darkmagenta', label = '')
ax5.spines['bottom'].set_visible(False)
ax5.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax6 = plt.subplot(gs[1])
x5 = Cu7PSe6_PDF['2q']
y5 = Cu7PSe6_PDF['Intensity']
ax6.set_xlim(24, 60)
ax6.set_ylim(6,15)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x5, [0], y5, lw=1, color = 'royalblue', label = '')
ax6.spines['bottom'].set_visible(False)
ax6.spines['top'].set_visible(False)
ax6.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

fig.text(0.82, .85, 'purge', ha='center', va='center', color = 'darkmagenta', fontsize = 12)
fig.text(0.83, .81, 'trap', ha='center', va='center', color = 'darkcyan', fontsize = 12)
fig.text(0.79, .77, 'purge/trap', ha='center', va='center', color = 'darkblue', fontsize = 12)

fig.text(0.952, .245, 'Cu$_7$PSe$_6$', ha='center', va='center', color = 'royalblue', fontsize = 10)
fig.text(0.952, .14, 'Cu$_3$PSe$_4$', ha='center', va='center', color = 'black', fontsize = 10)
fig.text(0.952, .192, 'Cu$_{2-x}$Se', ha='center', va='center', color = 'darkgreen', fontsize = 10)

fig.text(.5, 0.03, '$2\Theta$, Cu K$_{\\alpha}$ ($^\circ$)', ha='center', va='center',fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)

plt.savefig("headspace_0.05M_subplot.pdf", dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# # HDA:Cu3P ratio

# %%
NN_01_77 = pd.read_excel('NN-01-77_2021-03-02.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_77 = 0.5*NN_01_77['y_exp']

# %%
NN_01_84 = pd.read_csv('NN-01-84_2021-03-19_fit.txt',
                 sep=",",
                 header=1,
                 names=["2q", "y_exp", "diff", "y_calc"])
#print(NN_01_88)
y_exp_84 = NN_01_84['y_exp']+6000

# %%
NN_01_87 = pd.read_excel('NN-01-87_2021-03-26.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_87 = NN_01_87['y_exp']+12000

# %%
fig = plt.figure(figsize=(6,5))
gs = gridspec.GridSpec(4, 1, height_ratios=[1,0.1,.1,0.1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes.
plt.xlim(20,60)
ylim = (0,35000)
legLoc='upper right' #legend location

ax1 = plt.subplot(gs[3])
x = Cu3PSe4_PDF['2q']
y = Cu3PSe4_PDF['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(10,1100)
ax1.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax1.set_yticklabels([])
ax1.vlines(x, [0], y, lw=1, color = 'Black', label = '')
ax1.spines['bottom'].set_visible(True)
ax1.spines['top'].set_visible(False)
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax2 = plt.subplot(gs[2])
x1 = Cu2_xSe_PDF['2q']
y1 = Cu2_xSe_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,110)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x1, [0], y1, lw=1, color = 'darkgreen', label = '')
ax2.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax3 = plt.subplot(gs[0])
x2 = NN_01_77['2q']
y2 = y_exp_77
ax3.set_xlim(24, 60)
ax3.set_ylim(ylim)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x2, y2, lw=1, color = 'darkblue', label = '')
ax3.spines['bottom'].set_visible(False)
ax3.tick_params(direction = 'inout', top = True, bottom = False, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("Black")
    
plt.title('Cu$_3$P + 0.10M Se/ODE, 20 mins, f(Cu$_3$P:HDA)', fontsize = 12)
    
ax4 = plt.subplot(gs[0])
x3 = NN_01_84['2q']
y3 = y_exp_84
ax4.set_xlim(24, 60)
ax4.set_ylim(ylim)
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x3, y3, lw=1, color = 'darkcyan', label = '')
ax4.spines['bottom'].set_visible(False)
ax4.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax5 = plt.subplot(gs[0])
x4 = NN_01_87['2q']
y4 = y_exp_87
ax5.set_xlim(24, 60)
ax5.set_ylim(ylim)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x4, y4, lw=1, color = 'darkmagenta', label = '')
ax5.spines['bottom'].set_visible(False)
ax5.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax6 = plt.subplot(gs[1])
x5 = Cu7PSe6_PDF['2q']
y5 = Cu7PSe6_PDF['Intensity']
ax6.set_xlim(24, 60)
ax6.set_ylim(6,15)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x5, [0], y5, lw=1, color = 'royalblue', label = '')
ax6.spines['bottom'].set_visible(False)
ax6.spines['top'].set_visible(False)
ax6.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

fig.text(0.83, .85, '2:1', ha='center', va='center', color = 'darkmagenta', fontsize = 12)
fig.text(0.83, .81, '1:1', ha='center', va='center', color = 'darkcyan', fontsize = 12)
fig.text(0.80, .77, 'Excess', ha='center', va='center', color = 'darkblue', fontsize = 12)

fig.text(0.952, .245, 'Cu$_7$PSe$_6$', ha='center', va='center', color = 'royalblue', fontsize = 10)
fig.text(0.952, .14, 'Cu$_3$PSe$_4$', ha='center', va='center', color = 'black', fontsize = 10)
fig.text(0.952, .192, 'Cu$_{2-x}$Se', ha='center', va='center', color = 'darkgreen', fontsize = 10)

fig.text(.5, 0.03, '$2\Theta$, Cu K$_{\\alpha}$ ($^\circ$)', ha='center', va='center',fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)

plt.savefig("HDA-Cu3P_ratios_subplot.pdf", dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# # HDA:Cu3P 1:2 time

# %%
NN_01_87_1 = pd.read_excel('NN-01-87_2021-03-26.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_87_1 = NN_01_87_1['y_exp']

# %%
NN_01_88 = pd.read_excel('NN-01-88_2021-03-29.xlsx', #60 minutes
        usecols='A,B,C,D', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','y_exp','diff','y_calc'])
#print(NN_01_53)
y_exp_88 = NN_01_88['y_exp']+18000

# %%
NN_01_92 = pd.read_csv('NN-01-92_2021-04-01_fit.txt', #40 minutes
                 sep=",",
                 header=1,
                 names=["2q", "y_exp", "diff", "y_calc"])
#print(NN_01_88)
y_exp_92 = 0.7*NN_01_92['y_exp']+6000

# %%
NN_01_93 = pd.read_csv('NN-01-93_2021-04-02_fit.txt', #50 minutes
                 sep=",",
                 header=1,
                 names=["2q", "y_exp", "diff", "y_calc"])
#print(NN_01_88)
y_exp_93 = 0.7*NN_01_93['y_exp']+12000

# %%
fig = plt.figure(figsize=(6,5))
gs = gridspec.GridSpec(4, 1, height_ratios=[1,0.1,.1,0.1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes.
plt.xlim(20,60)
ylim = (0,40000)
legLoc='upper right' #legend location

ax1 = plt.subplot(gs[3])
x = Cu3PSe4_PDF['2q']
y = Cu3PSe4_PDF['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(10,1100)
ax1.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax1.set_yticklabels([])
ax1.vlines(x, [0], y, lw=1, color = 'Black', label = '')
ax1.spines['bottom'].set_visible(True)
ax1.spines['top'].set_visible(False)
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax2 = plt.subplot(gs[2])
x1 = Cu2_xSe_PDF['2q']
y1 = Cu2_xSe_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,110)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x1, [0], y1, lw=1, color = 'darkgreen', label = '')
ax2.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

ax3 = plt.subplot(gs[0])
x2 = NN_01_87['2q']
y2 = y_exp_87_1
ax3.set_xlim(24, 60)
ax3.set_ylim(ylim)
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x2, y2, lw=1, color = 'goldenrod', label = '')
ax3.spines['bottom'].set_visible(False)
ax3.tick_params(direction = 'inout', top = True, bottom = False, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("Black")
    
plt.title('2Cu$_3$P + 0.10M Se/ODE + HDA, trapping, f(time)', fontsize = 12)
    
ax4 = plt.subplot(gs[0])
x3 = NN_01_92['2q']
y3 = y_exp_92
ax4.set_xlim(24, 60)
ax4.set_ylim(ylim)
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x3, y3, lw=1, color = 'darkorange', label = '')
ax4.spines['bottom'].set_visible(False)
ax4.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax5 = plt.subplot(gs[0])
x4 = NN_01_93['2q']
y4 = y_exp_93
ax5.set_xlim(24, 60)
ax5.set_ylim(ylim)
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x4, y4, lw=1, color = 'orangered', label = '')
ax5.spines['bottom'].set_visible(False)
ax5.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax6 = plt.subplot(gs[0])
x5 = NN_01_88['2q']
y5 = y_exp_88
ax6.set_xlim(24, 60)
ax6.set_ylim(ylim)
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.plot(x5, y5, lw=1, color = 'darkred', label = '')
ax6.spines['bottom'].set_visible(False)
ax6.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

ax7 = plt.subplot(gs[1])
x6 = Cu7PSe6_PDF['2q']
y6 = Cu7PSe6_PDF['Intensity']
ax7.set_xlim(24, 60)
ax7.set_ylim(6,15)
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x6, [0], y6, lw=1, color = 'royalblue', label = '')
ax7.spines['bottom'].set_visible(False)
ax7.spines['top'].set_visible(False)
ax7.tick_params(direction = 'inout', top = False, bottom = False, right = False, left = False)

fig.text(0.82, .85, '60 mins', ha='center', va='center', color = 'darkred', fontsize = 12)
fig.text(0.82, .81, '50 mins', ha='center', va='center', color = 'orangered', fontsize = 12)
fig.text(0.82, .77, '40 mins', ha='center', va='center', color = 'darkorange', fontsize = 12)
fig.text(0.82, .73, '20 mins', ha='center', va='center', color = 'goldenrod', fontsize = 12)


fig.text(0.952, .245, 'Cu$_7$PSe$_6$', ha='center', va='center', color = 'royalblue', fontsize = 10)
fig.text(0.952, .14, 'Cu$_3$PSe$_4$', ha='center', va='center', color = 'black', fontsize = 10)
fig.text(0.952, .192, 'Cu$_{2-x}$Se', ha='center', va='center', color = 'darkgreen', fontsize = 10)

fig.text(.5, 0.03, '$2\Theta$, Cu K$_{\\alpha}$ ($^\circ$)', ha='center', va='center',fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)

plt.savefig("HDA-Cu3P_1-2_subplot.pdf", dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...
