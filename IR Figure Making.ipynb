# %% [markdown]
# # Package Calling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib notebook

# %%
def define_figure(xlabel="X",ylabel="Y"):
    # setup plot parameters
    fig = plt.figure(figsize=(10,8), dpi= 80, facecolor='w', edgecolor='k')
    ax = plt.subplot(111)
    ax.grid(b=True, which='major', axis='both', color='#808080', linestyle='--')
    ax.set_xlabel(xlabel,size=20)
    ax.set_ylabel(ylabel,size=20)
    plt.tick_params(axis='both',labelsize=20)
    return ax

# %%
pd.read_excel
# Out:
# <function pandas.io.excel._base.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)>

# %% [markdown]
# Let's use the read_excel function to import some data from the "Arbin_Cycling_Data.xlsx" file included. Open the file in excel to examine its format. We want to get the "Cycle Index", "Charge Capacity", and "Discharge Capacity" data columns from the last sheet in the workbook. Find those columns and fill in the "usecols" parameter below with the corresponding column letters. Note that different instruments may format their .xlsx files differently, so it's best to doublecheck the columns in the sheet you want to upload.
#
# The code below make take a few moments to run because it is running through many operations:

# %%
IR_data = pd.read_excel('ODE.xlsx',  #excel file where data is located
        sheetname=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_data)

#Errors can occur here depending on the version of python you have installed.
#See (parse_cols v. usecols) 
#https://stackoverflow.com/questions/48199383/getting-an-error-importing-excel-file-into-pandas-selecting-the-usecols-paramete
#And (sheetname v. sheet_name) 
#https://stackoverflow.com/questions/47975866/pandas-read-excel-parameter-sheet-name-not-working
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
plt.plot(IR_data['wavenumbers'],IR_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('ODE from the cabinet')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
IR_1_data = pd.read_excel('150_3.xlsx',  #excel file where data is located
        sheetname=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_1_data)

# %%
plt.plot(IR_1_data['wavenumbers'],IR_1_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 150')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
IR_2_data = pd.read_excel('200.xlsx',  #excel file where data is located
        sheetname=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_2_data)

# %%
plt.plot(IR_2_data['wavenumbers'],IR_2_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3133.9130,655.7111)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 200')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, '2nd ex-situ at 200')

# %%
IR_3_data = pd.read_excel('225.xlsx',  #excel file where data is located
        sheetname=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_3_data)

# %%
plt.plot(IR_3_data['wavenumbers'],IR_3_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 225')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, '2nd ex-situ at 225')

# %%
IR_4_data = pd.read_excel('250.xlsx',  #excel file where data is located
        sheet_name=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_4_data)

# %%
plt.plot(IR_4_data['wavenumbers'],IR_4_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,559.2830)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 250')
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, '2nd ex-situ at 250')

# %%
IR_5_data = pd.read_excel('300.xlsx',  #excel file where data is located
        sheetname=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_5_data)

# %%
plt.plot(IR_5_data['wavenumbers'],IR_5_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 300')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 300')

# %%
IR_6_data = pd.read_excel('300_10mins.xlsx',  #excel file where data is located
        sheetname=-1,                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B',            #these are the columns in the excel sheet that data is loaded from
        names=['wavenumbers','transmittance'])          #variable names corresponding to each data column

#check to verify data was loaded properly and see how the imported data are structured
#print(IR_6_data)

# %%
plt.plot(IR_6_data['wavenumbers'],IR_6_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 300 for 10 mins')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 300 for 10 mins')

# %%
plt.plot(IR_data['wavenumbers'],IR_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('ODE from the cabinet')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(IR_1_data['wavenumbers'],IR_1_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 150')
plt.show()

#terminal alkene peaks: 3080, 1820, 1645, 900
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(IR_2_data['wavenumbers'],IR_2_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3133.9130,655.7111)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 200')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 200')

# %%
plt.plot(IR_3_data['wavenumbers'],IR_3_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 225')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 225')

# %%
plt.plot(IR_4_data['wavenumbers'],IR_4_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,559.2830)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 250')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 250')

# %%
plt.plot(IR_5_data['wavenumbers'],IR_5_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 300')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 300')

# %%
plt.plot(IR_6_data['wavenumbers'],IR_6_data['transmittance'])

plt.xlabel('wavenumbers $(cm^{-1})$')
plt.ylabel('% transmittance')
plt.xlim(3211.0560,557.3544)
#plt.ylim(0,600)
plt.legend()   #This function makes a legend for data with labels that were specified when they were plotted
plt.title('2nd ex-situ at 300 for 10 mins')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1, '2nd ex-situ at 300 for 10 mins')
