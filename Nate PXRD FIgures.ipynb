# %% [markdown]
# # Enter input file names here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
import matplotlib.gridspec as gridspec
# %matplotlib notebook

# %%
pd.read_excel
# Out:
# <function pandas.io.excel._base.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)>

# %%
Se_PDF = pd.read_excel('Se PDF 00-042-1425.xlsx',  #excel file where data is located                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(Se_PDF)

# %%
Cu3PSe4_PDF = pd.read_excel('Cu3PSe4 PDF 04-006-8347.xlsx',  #excel file where data is located                                #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(Cu3PSe4_PDF)

# %%
Cu3P_PDF = pd.read_excel('Cu3P PDF 01-071-2261.xlsx',                                 #selects the last sheet in the excel workbook to be used
        usecols='A,C', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(Cu3P_PDF)

# %%
CuSe2_PDF = pd.read_excel('CuSe2 PDF 00-026-1115.xlsx',                                #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
CuSe_PDF = pd.read_excel('CuSe PDF 00-049-1457.xlsx',                                 #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %%
CuSe2_2178_PDF = pd.read_excel('CuSe2 PDF 04-004-2178.xlsx',                                #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %%
CuRSe_PDF = pd.read_excel('Cu0.87Se PDF 01-089-2734.xlsx',                             #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column
# R stands for 0.87

# %%
Cu7PSe6_PDF = pd.read_excel('Cu7PSe6 PDF 00-033-0482.xlsx',                          #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column
# R stands for 0.87

# %%
Cu2_xSe_PDF = pd.read_excel('Cu2-xSex PDF 00-006-0680.xlsx',             #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column
# R stands for 0.87

# %% [markdown]
# # Cu3PSe4 Individual Studies

# %% [markdown]
# ## Data Calling

# %%
Cu3PSe4_squalane = pd.read_excel('Cu3PSe4_2020-03-19_squalane.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu3PSe4_2020_03_19_overnight = pd.read_excel('Cu3PSe4_2020-03-19_overnight.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu3PSe4_NN_01_36 = pd.read_excel('Cu3PSe4_2020-06-15_NN-01-036.xlsx',                                #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu3PSe4_NN_01_39 = pd.read_excel('Cu3PSe4_2020-06-28_NN-01-39.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu3PSe4_NN_01_41 = pd.read_excel('Cu3PSe4_2020-06-30_NN-01-41.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu3PSe4_NN_01_43 = pd.read_excel('Cu3PSe4_2020_07_16_NN_01_43.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu3PSe4_NN_01_48 = pd.read_excel('Cu3PSe4_2020-09-03_NN-01-48.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
Cu7PSe6_NN_01_69 = pd.read_excel('Cu7PSe6_2021-02-09_NN-01-69.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
Cu7PSe6_NN_01_81 = pd.read_excel('Cu7PSe6_2021-03-11_NN-01-81.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
Cu7PSe6_NN_01_82 = pd.read_excel('Cu7PSe6_2021-03-12_NN-01-82.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
Cu7PSe6_NN_01_84 = pd.read_excel('Cu7PSe6_2021-03-19_NN-01-84.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %%
Cu7PSe6_NN_01_85 = pd.read_excel('Cu7PSe6_2021-03-22_NN-01-85.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])

# %% [markdown]
# ## Cannula Transfer Single Plot

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,6)) 
gs = gridspec.GridSpec(5, 1, height_ratios=[2,1,1,1,1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc = 'upper right'

ax1 = plt.subplot(gs[0])
x = Cu7PSe6_NN_01_85['2q']
y = Cu7PSe6_NN_01_85['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(5, 25000)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=0.75, color = 'black', label = 'Cu$_7$PSe$_6$ NN-01-85')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("black")
    
ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_PDF['2q']
y2 = Cu3PSe4_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x2,[0],y2, color = 'darkgreen', label = 'Cu$_3$PSe$_4$ PDF 03-065-1307')
ax2.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("darkgreen")

ax3 = plt.subplot(gs[2])
x3 = Cu7PSe6_PDF['2q']
y3 = Cu7PSe6_PDF['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(5,110)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.vlines(x3,[0],y3, color = 'mediumseagreen', label = 'Cu$_7$PSe$_6$ PDF 00-033-0482')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("mediumseagreen")
    
ax4 = plt.subplot(gs[3])
x4 = Cu2_xSe_PDF['2q']
y4 = Cu2_xSe_PDF['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(5,170)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.vlines(x4,[0],y4, color = 'darkcyan', label = 'Cu$_{2-x}$Se$_x$ PDF 00-006-0680')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)


leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("darkcyan")
    
ax5 = plt.subplot(gs[4])
x5 = CuRSe_PDF['2q']
y5 = CuRSe_PDF['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(2,1200)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([20,25,30,35,40,45,50,55,60],fontsize=12)
ax5.set_yticklabels([])
ax5.vlines(x5,[0],y5, color = 'steelblue', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=12)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("steelblue")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize=12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize=12)
plt.savefig("Cu7PSe6_2021_03_22_NN-01-85.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# ## Cannula Transfer subplots

# %%
fig = plt.figure(figsize=(7.5,8)) 
gs = gridspec.GridSpec(7, 1, height_ratios=[2,2,2,2,1,1,1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_NN_01_43['2q']
y = Cu3PSe4_NN_01_43['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,11500)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'black', label = 'A')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("black")
    
ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_NN_01_39['2q']
y2 = Cu3PSe4_NN_01_39['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,3500)
#ax2.set_ylabel('Intensity (a.u.)')
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2,lw=1, color = 'darkmagenta', label = 'B')
ax2.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("darkmagenta")

ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_NN_01_41['2q']
y3 = Cu3PSe4_NN_01_41['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(10,10000)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3,lw=1, color = 'darkcyan', label = 'C')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("darkcyan")

ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_NN_01_36['2q']
y4 = Cu3PSe4_NN_01_36['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,10000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4,lw=1, color = 'darkblue', label = 'D')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("darkblue")

ax5 = plt.subplot(gs[4])
x5 = Cu2_xSe_PDF['2q']
y5 = Cu2_xSe_PDF['Intensity']
ax5.set_xlim(24, 60)
ax5.set_ylim(5,170)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.vlines(x5,[0],y5, lw=2, color = 'darkcyan', label = 'Cu$_{2-x}$Se')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)


leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("darkcyan")
    
ax6 = plt.subplot(gs[5])
x6 = Cu3PSe4_PDF['2q']
y6 = Cu3PSe4_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,1500)
#ax2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6,[0],y6, lw=2, color = 'steelblue', label = 'Cu$_3$PSe$_4$')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("steelblue")
    
ax7 = plt.subplot(gs[6])
x7 = Cu7PSe6_PDF['2q']
y7 = Cu7PSe6_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(2,120)
#ax2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize=18)
ax7.set_yticklabels([])
ax7.vlines(x7,[0],y7, lw=2, color = 'darkslateblue', label = 'Cu$_7$PSe$_6$')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("darkslateblue")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.04, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize=18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical',fontsize=18)
plt.savefig("Cu3PSe4 Cannula Transfer subplots.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="749.9999837441882">

# %% [markdown]
# ## Overnight

# %%
Cu3PSe4_2020_03_19_overnight = pd.read_excel('Cu3PSe4_2020-03-19_overnight.xlsx',                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(6,5)) 
gs = gridspec.GridSpec(5, 1, height_ratios=[2.5,1,1,1,1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(24,60)
legLoc = 'upper right'
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_2020_03_19_overnight['2q']
y = Cu3PSe4_2020_03_19_overnight['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,9500)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'black', label = 'B')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("black")
    
ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_PDF['2q']
y2 = Cu3PSe4_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(10,1500)
#ax2.set_ylabel('Intensity (a.u.)')
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.vlines(x2,[0],y2, lw=2, color = 'darkblue', label = 'Cu$_3$PSe$_4$')
ax2.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("darkblue")
    
ax3 = plt.subplot(gs[2])
x3 = Se_PDF['2q']
y3 = Se_PDF['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(0,120)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.vlines(x3,[0],y3, lw=2, color = 'steelblue', label = 'Se')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("steelblue")
    
ax4 = plt.subplot(gs[3])
x4 = CuRSe_PDF['2q']
y4 = CuRSe_PDF['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(2,1200)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([],fontsize=16)
ax4.set_yticklabels([])
ax4.vlines(x4,[0],y4, lw=2, color = 'darkcyan', label = 'Cu$_{0.87}$Se')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("darkcyan")

ax5 = plt.subplot(gs[4])
x5 = Cu7PSe6_PDF['2q']
y5 = Cu7PSe6_PDF['Intensity']
ax5.set_xlim(24, 60)
ax5.set_ylim(5,120)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([20,25,30,35,40,45,50,55,60],fontsize=16)
ax5.set_yticklabels([])
ax5.vlines(x5,[0],y5, lw=2, color = 'green', label = 'Cu$_7$PSe$_6$')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("green")

#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.03, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center',fontsize=18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize=18)
plt.savefig("Cu3PSe4 Overnight Final_1.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %% [markdown]
# ## Squalane

# %%
fig = plt.figure(figsize=(6,5)) 
gs = gridspec.GridSpec(2, 1, height_ratios=[1.5,1]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(24,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_squalane['2q']
y = Cu3PSe4_squalane['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,8000)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'black', label = 'A')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("black")
    
ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_PDF['2q']
y2 = Cu3PSe4_PDF['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(0,1500)
#ax2.set_ylabel('Intensity (a.u.)')
ax2.set_xticklabels([20,25,30,35,40,45,50,55,60],fontsize=16)
ax2.set_yticklabels([])
ax2.vlines(x2,[0], y2,lw=2, color = 'darkgreen', label = 'Cu$_3$PSe$_4$')
ax2.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("darkgreen")
    
fig.text(.5, 0.03, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center',fontsize=18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical',fontsize=18)
plt.savefig("Cu3PSe4 Squalane Final.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
