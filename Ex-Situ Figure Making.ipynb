# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
import matplotlib.gridspec as gridspec
# %matplotlib notebook

# %%
pd.read_excel
# Out:
# <function pandas.io.excel._base.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)>

# %% [markdown]
# # PDF Data Calling

# %%
Se_PDF = pd.read_excel('Se PDF 00-042-1425.xlsx',                                   #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(Se_PDF)

# %%
Cu3PSe4_PDF = pd.read_excel('Cu3PSe4 PDF 04-006-8347.xlsx',                                #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(Cu3PSe4_PDF)

# %%
Cu3P_PDF = pd.read_excel('Cu3P PDF 01-071-2261.xlsx',                            #selects the last sheet in the excel workbook to be used
        usecols='A,C', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(Cu3P_PDF)

# %%
CuSe2_PDF = pd.read_excel('CuSe2 PDF 00-026-1115.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %%
CuSe_PDF = pd.read_excel('CuSe PDF 00-049-1457.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %%
CuSe2_2178_PDF = pd.read_excel('CuSe2 PDF 04-004-2178.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %%
CuRSe_PDF = pd.read_excel('Cu0.87Se PDF 01-089-2734.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column
# R stands for 0.87

# %% [markdown]
# # NN-01-65

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_65 = pd.read_excel('Cu3PSe4_2020_12_18_NN-01-65.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_200_NN_01_65 = pd.read_excel('Cu3PSe4_2020_12_18_NN-01-65.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_225_NN_01_65 = pd.read_excel('Cu3PSe4_2020_12_18_NN-01-65.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_250_NN_01_65 = pd.read_excel('Cu3PSe4_2020_12_18_NN-01-65.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_300_NN_01_65 = pd.read_excel('Cu3PSe4_2020_12_18_NN-01-65.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_300t_NN_01_65 = pd.read_excel('Cu3PSe4_2020_12_18_NN-01-65.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(8, 1, height_ratios=[1,1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_65['2q']
y = Cu3PSe4_300_NN_01_65['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,2500)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
plt.title('Cu$_3$PSe$_4$ Limited Cu$_3$P NN-01-65 (2.5 min)', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_65['2q']
y2 = Cu3PSe4_250_NN_01_65['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,3000)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_65['2q']
y3 = Cu3PSe4_225_NN_01_65['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,1700)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_65['2q']
y4 = Cu3PSe4_200_NN_01_65['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,3500)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_65['2q']
y5 = Cu3PSe4_150_NN_01_65['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,19000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=1, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,110)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, lw=2, color = 'k', label = 'Se PDF 00-042-1425')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = CuRSe_PDF['2q']
y7 = CuRSe_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(5,1300)
#a2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("orange")
    
ax8 = plt.subplot(gs[7])
x8 = Cu3PSe4_PDF['2q']
y8 = Cu3PSe4_PDF['Intensity']
ax8.set_xlim(24,60)
ax8.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax8.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax8.set_yticklabels([])
ax8.vlines(x8, [0], y8, lw=2, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax8.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax8.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_8 = ax8.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_8.legendHandles:
    item.set_visible(False)
for text in leg_8.get_texts():
    text.set_color("green")

fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center',fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_2020_12_18_NN-01-65.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # NN-01-63

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_63 = pd.read_excel('Cu3PSe4_2020_12_16_NN-01-63.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_200_NN_01_63 = pd.read_excel('Cu3PSe4_2020_12_16_NN-01-63.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_225_NN_01_63 = pd.read_excel('Cu3PSe4_2020_12_16_NN-01-63.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_250_NN_01_63 = pd.read_excel('Cu3PSe4_2020_12_16_NN-01-63.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_300_NN_01_63 = pd.read_excel('Cu3PSe4_2020_12_16_NN-01-63.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_300t_NN_01_63 = pd.read_excel('Cu3PSe4_2020_12_16_NN-01-63.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(8, 1, height_ratios=[1,1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_63['2q']
y = Cu3PSe4_300_NN_01_63['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,3000)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
plt.title('Cu$_3$PSe$_4$ Limited Cu$_3$P NN-01-63', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_63['2q']
y2 = Cu3PSe4_250_NN_01_63['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,2000)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_63['2q']
y3 = Cu3PSe4_225_NN_01_63['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,1500)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_63['2q']
y4 = Cu3PSe4_200_NN_01_63['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,3000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_63['2q']
y5 = Cu3PSe4_150_NN_01_63['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,22000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=1, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,110)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, lw=2, color = 'k', label = 'Se PDF 00-042-1425')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = CuRSe_PDF['2q']
y7 = CuRSe_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(5,1300)
#a2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("orange")
    
ax8 = plt.subplot(gs[7])
x8 = Cu3PSe4_PDF['2q']
y8 = Cu3PSe4_PDF['Intensity']
ax8.set_xlim(24,60)
ax8.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax8.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax8.set_yticklabels([])
ax8.vlines(x8, [0], y8, lw=2, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax8.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax8.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_8 = ax8.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_8.legendHandles:
    item.set_visible(False)
for text in leg_8.get_texts():
    text.set_color("green")

fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center',fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_2020_12_16_NN-01-63.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # NN-01-61

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_61 = pd.read_excel('Cu3PSe4_2020_12_09_NN-01-61.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_200_NN_01_61 = pd.read_excel('Cu3PSe4_2020_12_09_NN-01-61.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_225_NN_01_61 = pd.read_excel('Cu3PSe4_2020_12_09_NN-01-61.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_250_NN_01_61 = pd.read_excel('Cu3PSe4_2020_12_09_NN-01-61.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_300_NN_01_61 = pd.read_excel('Cu3PSe4_2020_12_09_NN-01-61.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

Cu3PSe4_300t_NN_01_61 = pd.read_excel('Cu3PSe4_2020_12_09_NN-01-61.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(8, 1, height_ratios=[1,1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_61['2q']
y = Cu3PSe4_300_NN_01_61['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,4000)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
plt.title('Cu$_3$PSe$_4$ Limited Cu$_3$P NN-01-61 (3 min)', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_61['2q']
y2 = Cu3PSe4_250_NN_01_61['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,1000)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_61['2q']
y3 = Cu3PSe4_225_NN_01_61['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,1700)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_61['2q']
y4 = Cu3PSe4_200_NN_01_61['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,30000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_61['2q']
y5 = Cu3PSe4_150_NN_01_61['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,17000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=1, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,110)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, lw=2, color = 'k', label = 'Se PDF 00-042-1425')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = CuRSe_PDF['2q']
y7 = CuRSe_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(5,1300)
#a2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("orange")
    
ax8 = plt.subplot(gs[7])
x8 = Cu3PSe4_PDF['2q']
y8 = Cu3PSe4_PDF['Intensity']
ax8.set_xlim(24,60)
ax8.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax8.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax8.set_yticklabels([])
ax8.vlines(x8, [0], y8, lw=2, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax8.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax8.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_8 = ax8.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_8.legendHandles:
    item.set_visible(False)
for text in leg_8.get_texts():
    text.set_color("green")

fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center',fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_2020_12_09_NN-01-61.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # NN-01-31

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_31 = pd.read_excel('Cu3PSe4_2020_03_21_NN-01-31.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_200_NN_01_31 = pd.read_excel('Cu3PSe4_2020_03_21_NN-01-31.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_225_NN_01_31 = pd.read_excel('Cu3PSe4_2020_03_21_NN-01-31.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_250_NN_01_31 = pd.read_excel('Cu3PSe4_2020_03_21_NN-01-31.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300_NN_01_31 = pd.read_excel('Cu3PSe4_2020_03_21_NN-01-31.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300t_NN_01_31 = pd.read_excel('Cu3PSe4_2020_03_21_NN-01-31.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(8, 1, height_ratios=[1,1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_31['2q']
y = Cu3PSe4_300_NN_01_31['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,1500)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
#plt.title('Cu$_3$PSe$_4$ Limited Cu$_3$P', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_31['2q']
y2 = Cu3PSe4_250_NN_01_31['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,4000)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_31['2q']
y3 = Cu3PSe4_225_NN_01_31['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,1700)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_31['2q']
y4 = Cu3PSe4_200_NN_01_31['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,30000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_31['2q']
y5 = Cu3PSe4_150_NN_01_31['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,40000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=1, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,110)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, lw=2, color = 'k', label = 'Se')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = CuRSe_PDF['2q']
y7 = CuRSe_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(5,1300)
#a2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'orange', label = 'Cu$_{0.87}$Se')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("orange")
    
ax8 = plt.subplot(gs[7])
x8 = Cu3PSe4_PDF['2q']
y8 = Cu3PSe4_PDF['Intensity']
ax8.set_xlim(24,60)
ax8.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax8.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 18)
ax8.set_yticklabels([])
ax8.vlines(x8, [0], y8, lw=2, color = 'green', label = 'Cu$_3$PSe$_4$')
ax8.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax8.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_8 = ax8.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_8.legendHandles:
    item.set_visible(False)
for text in leg_8.get_texts():
    text.set_color("green")

fig.text(.5, 0.03, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center',fontsize = 20)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 20)
plt.savefig("Cu3PSe4_2020_03_21_NN-01-31.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(7, 1, height_ratios=[1,1,.8,.8,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_250_NN_01_31['2q']
y = Cu3PSe4_250_NN_01_31['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,4000)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '250')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")

#plt.title('Cu$_3$PSe$_4$ Limited Cu$_3$P 225-250', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_225_NN_01_31['2q']
y2 = Cu3PSe4_225_NN_01_31['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,1800)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '225')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Se_PDF['2q']
y3 = Se_PDF['Intensity']
ax3.set_xlim(24,60)
ax3.set_ylim(0,120)
#a2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.vlines(x3, [0], y3, color = 'k', label = 'Se')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("black")
    
ax4 = plt.subplot(gs[3])
x4 = CuRSe_PDF['2q']
y4 = CuRSe_PDF['Intensity']
ax4.set_xlim(24,60)
ax4.set_ylim(5,1200)
#a2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.vlines(x4, [0], y4, color = 'green', label = 'Cu$_{0.87}$Se')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("green")
    
ax5 = plt.subplot(gs[4])
x5 = CuSe2_PDF['2q']
y5 = CuSe2_PDF['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,130)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.vlines(x5, [0], y5, color = 'orange', label = 'CuSe$_2$')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("orange")

ax6 = plt.subplot(gs[5])
x6 = CuSe2_2178_PDF['2q']
y6 = CuSe2_2178_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, color = 'orangered', label = 'CuSe$_2$')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("orangered")

ax7 = plt.subplot(gs[6])
x7 = Cu3PSe4_PDF['2q']
y7 = Cu3PSe4_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize =18)
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, color = 'darkred', label = 'Cu$_3$PSe$_4$')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=16)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("darkred")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.03, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 20)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 20)
plt.savefig("Cu3PSe4_2020_03_21_NN-01-31_225-250.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # NN-01-21

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_200_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx',  #selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_225_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_250_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300t_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300_1hr_NN_01_21 = pd.read_excel('Cu3PSe4_2020_03_17_NN-01-21.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='S,T', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(7, 1, height_ratios=[1,1,1,1,1,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(24,60)
legLoc = 'upper right'
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_21['2q']
y = Cu3PSe4_300_NN_01_21['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,1200)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")

plt.title('Cu$_3$PSe$_4$ 5 min aliquot', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_21['2q']
y2 = Cu3PSe4_250_NN_01_21['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,1200)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_21['2q']
y3 = Cu3PSe4_225_NN_01_21['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,600)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_21['2q']
y4 = Cu3PSe4_200_NN_01_21['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,8000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_21['2q']
y5 = Cu3PSe4_150_NN_01_21['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,11000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=1, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,110)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, lw=2, color = 'k', label = 'Se PDF 01-078-2640')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = Cu3PSe4_PDF['2q']
y7 = Cu3PSe4_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(10,1750)
#ax2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("green")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_2020_03_17_NN-01-21_FINAL.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # NN-01-16

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_16 = pd.read_excel('Cu3PSe4_2020_03_05_NN-01-16.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_200_NN_01_16 = pd.read_excel('Cu3PSe4_2020_03_05_NN-01-16.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_225_NN_01_16 = pd.read_excel('Cu3PSe4_2020_03_05_NN-01-16.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_250_NN_01_16 = pd.read_excel('Cu3PSe4_2020_03_05_NN-01-16.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300_NN_01_16 = pd.read_excel('Cu3PSe4_2020_03_05_NN-01-16.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300t_NN_01_16 = pd.read_excel('Cu3PSe4_2020_03_05_NN-01-16.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(8, 1, height_ratios=[1,1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
legLoc = 'upper right'
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_16['2q']
y = Cu3PSe4_300_NN_01_16['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,1200)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
plt.title('Cu$_3$PSe$_4$ 2 min aliquot', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_16['2q']
y2 = Cu3PSe4_250_NN_01_16['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,1200)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_16['2q']
y3 = Cu3PSe4_225_NN_01_16['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,3300)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_16['2q']
y4 = Cu3PSe4_200_NN_01_16['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,80000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_16['2q']
y5 = Cu3PSe4_150_NN_01_16['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,27000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=1, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,120)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, lw=2, color = 'k', label = 'Se PDF 00-042-1425')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = CuRSe_PDF['2q']
y7 = CuRSe_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(10,1300)
#a2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("orange")
    
ax8 = plt.subplot(gs[7])
x8 = Cu3PSe4_PDF['2q']
y8 = Cu3PSe4_PDF['Intensity']
ax8.set_xlim(24,60)
ax8.set_ylim(10,1750)
#ax2.set_ylabel('Intensity (a.u.)')
ax8.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax8.set_yticklabels([])
ax8.vlines(x8, [0], y8, lw=2, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax8.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax8.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_8 = ax8.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_8.legendHandles:
    item.set_visible(False)
for text in leg_8.get_texts():
    text.set_color("green")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_2020_03_05_NN-01-16.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(7, 1, height_ratios=[1,1,.6,.6,.6,.6,.6]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(24,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_250_NN_01_16['2q']
y = Cu3PSe4_250_NN_01_16['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,1200)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = '250')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
plt.title('Cu$_3$PSe$_4$ 2 min aliquot 225-250', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_225_NN_01_16['2q']
y2 = Cu3PSe4_225_NN_01_16['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,3200)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = '225')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Se_PDF['2q']
y3 = Se_PDF['Intensity']
ax3.set_xlim(24,60)
ax3.set_ylim(0,120)
#a2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.vlines(x3, [0], y3, lw=2, color = 'k', label = 'Se PDF 00-042-1425')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("black")
    
ax4 = plt.subplot(gs[3])
x4 = CuRSe_PDF['2q']
y4 = CuRSe_PDF['Intensity']
ax4.set_xlim(24,60)
ax4.set_ylim(5,1200)
#a2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.vlines(x4, [0], y4, lw=2, color = 'green', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("green")
    
ax5 = plt.subplot(gs[4])
x5 = CuSe2_PDF['2q']
y5 = CuSe2_PDF['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,130)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.vlines(x5, [0], y5, lw=2, color = 'orange', label = 'CuSe$_2$ PDF 00-026-1115')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("orange")

ax6 = plt.subplot(gs[5])
x6 = CuSe2_2178_PDF['2q']
y6 = CuSe2_2178_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6,lw=2, color = 'orangered', label = 'CuSe$_2$ PDF 04-004-2178')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("orangered")

ax7 = plt.subplot(gs[6])
x7 = Cu3PSe4_PDF['2q']
y7 = Cu3PSe4_PDF['Intensity']
ax7.set_xlim(24,60)
#ax7.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'darkred', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("darkred")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_2020_03_05_NN-01-16_225-250.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # Figure 225 subplot

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(7, 1, height_ratios=[1,1,1,1,.6,.6,.6]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(24,60)
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)
legLoc='upper right'

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_225_NN_01_31['2q']
y = Cu3PSe4_225_NN_01_31['Intensity']
ax1.set_xlim(24, 60)
#ax1.set_ylim(50,1200)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=1, color = 'tab:cyan', label = 'NN-01-31')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
#plt.title('Cu$_3$PSe$_4$ 2 min aliquot 225-250', fontsize = 12)

ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_225_NN_01_21['2q']
y2 = Cu3PSe4_225_NN_01_21['Intensity']
ax2.set_xlim(24, 60)
#ax2.set_ylim(50,3200)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=1, color = 'blue', label = 'NN-01-21')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_16['2q']
y3 = Cu3PSe4_225_NN_01_16['Intensity']
ax3.set_xlim(24,60)
#ax3.set_ylim(0,120)
#a2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=1, color = 'k', label = 'NN-01-16')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("black")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_225_NN_01_13['2q']
y4 = Cu3PSe4_225_NN_01_13['Intensity']
ax4.set_xlim(24,60)
#ax4.set_ylim(5,1200)
#a2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=1, color = 'green', label = 'NN-01-13')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=14)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("green")
    
ax5 = plt.subplot(gs[4])
x5 = CuRSe_PDF['2q']
y5 = CuRSe_PDF['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,1350)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.vlines(x5, [0], y5, lw=2, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("orange")

ax6 = plt.subplot(gs[5])
x6 = CuSe2_2178_PDF['2q']
y6 = CuSe2_2178_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6,lw=2, color = 'orangered', label = 'CuSe$_2$ PDF 04-004-2178')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("orangered")

ax7 = plt.subplot(gs[6])
x7 = Cu3PSe4_PDF['2q']
y7 = Cu3PSe4_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(10,1300)
#ax2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 16)
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, lw=2, color = 'darkred', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=11)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("darkred")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 18)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 18)
plt.savefig("Cu3PSe4_subplot_225.pdf", dpi=10000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %% [markdown]
# # NN-01-13

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_13 = pd.read_excel('Cu3PSe4_2020_02_25_NN-01-13.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_200_NN_01_13 = pd.read_excel('Cu3PSe4_2020_02_25_NN-01-13.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_225_NN_01_13 = pd.read_excel('Cu3PSe4_2020_02_25_NN-01-13.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_250_NN_01_13 = pd.read_excel('Cu3PSe4_2020_02_25_NN-01-13.xlsx', #selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300_NN_01_13 = pd.read_excel('Cu3PSe4_2020_02_25_NN-01-13.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='M,N', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_300t_NN_01_13 = pd.read_excel('Cu3PSe4_2020_02_25_NN-01-13.xlsx',#selects the last sheet in the excel workbook to be used
        usecols='P,Q', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(8, 1, height_ratios=[1,1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
legLoc = 'upper right'
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_300_NN_01_13['2q']
y = Cu3PSe4_300_NN_01_13['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,1600)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=0.75, color = 'tab:cyan', label = '300')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")

plt.title('Cu$_3$PSe$_4$ limited Cu$_3$P', fontsize = 12)
ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_250_NN_01_13['2q']
y2 = Cu3PSe4_250_NN_01_13['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,2000)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=0.75, color = 'blue', label = '250')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_225_NN_01_13['2q']
y3 = Cu3PSe4_225_NN_01_13['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,1400)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=0.75, color = 'purple', label = '225')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_200_NN_01_13['2q']
y4 = Cu3PSe4_200_NN_01_13['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,12000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=0.75, color = 'red', label = '200')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Cu3PSe4_150_NN_01_13['2q']
y5 = Cu3PSe4_150_NN_01_13['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(10,3000)
#ax2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.plot(x5, y5, lw=0.75, color = 'deeppink', label = '150')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("deeppink")
    
ax6 = plt.subplot(gs[5])
x6 = Se_PDF['2q']
y6 = Se_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(0,130)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, color = 'k', label = 'Se PDF 00-042-1425')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("black")
    
ax7 = plt.subplot(gs[6])
x7 = CuRSe_PDF['2q']
y7 = CuRSe_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(10,1200)
#a2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([])
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("orange")
    
ax8 = plt.subplot(gs[7])
x8 = Cu3PSe4_PDF['2q']
y8 = Cu3PSe4_PDF['Intensity']
ax8.set_xlim(24,60)
ax8.set_ylim(10,1750)
#ax2.set_ylabel('Intensity (a.u.)')
ax8.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize =12)
ax8.set_yticklabels([])
ax8.vlines(x8, [0], y8, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 03-065-1307')
ax8.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax8.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_8 = ax8.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_8.legendHandles:
    item.set_visible(False)
for text in leg_8.get_texts():
    text.set_color("green")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)
plt.savefig("Cu3PSe4_2020_02_25_NN-01-13.pdf", dpi=10000)
plt.show()

# %% [markdown]
# # NN-01-07

# %% [markdown]
# ## File Calling

# %%
Cu3PSe4_150_NN_01_07 = pd.read_excel('Cu3PSe4_2020_01_29_NN-01-07.xlsx',  #excel file where data is located
        sheetname=-1,                               #selects the last sheet in the excel workbook to be used
        usecols='A,B', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_200_NN_01_07 = pd.read_excel('Cu3PSe4_2020_01_29_NN-01-07.xlsx',  #excel file where data is located
        sheetname=-1,                               #selects the last sheet in the excel workbook to be used
        usecols='D,E', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_225_NN_01_07 = pd.read_excel('Cu3PSe4_2020_01_29_NN-01-07.xlsx',  #excel file where data is located
        sheetname=-1,                               #selects the last sheet in the excel workbook to be used
        usecols='G,H', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

Cu3PSe4_250_NN_01_07 = pd.read_excel('Cu3PSe4_2020_01_29_NN-01-07.xlsx',  #excel file where data is located
        sheetname=-1,                               #selects the last sheet in the excel workbook to be used
        usecols='J,K', #these are the columns in the excel sheet that data is loaded from
        #userows='1:10'
        names=['2q','Intensity'])          #variable names corresponding to each data column

#print(CuSe2_PDF)

# %% [markdown]
# ## Figure Making

# %%
import matplotlib.colors as mcolors
fig = plt.figure(figsize=(7,7)) 
gs = gridspec.GridSpec(7, 1, height_ratios=[1,1,1,1,.8,.8,.8]) #rows, columns, [ht ratios] 
gs.update(wspace=0.025, hspace=0.0) # set the spacing between axes. 
#axs = gs.subplots(sharex=True, sharey=True)
plt.xlim(20,60)
legLoc = 'upper right'
#plt.xlabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)',fontsize=18)
#plt.ylabel('Intensity (a.u.)',fontsize=18)

ax1 = plt.subplot(gs[0])
x = Cu3PSe4_250_NN_01_07['2q']
y = Cu3PSe4_250_NN_01_07['Intensity']
ax1.set_xlim(24, 60)
ax1.set_ylim(50,1800)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.plot(x, y, lw=0.75, color = 'tab:cyan', label = '250')
ax1.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax1.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_1 = ax1.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_1.legendHandles:
    item.set_visible(False)
for text in leg_1.get_texts():
    text.set_color("tab:cyan")
    
plt.title('Cu$_3$PSe$_4$ initial ex-situ study', fontsize = 12)
ax2 = plt.subplot(gs[1])
x2 = Cu3PSe4_225_NN_01_07['2q']
y2 = Cu3PSe4_225_NN_01_07['Intensity']
ax2.set_xlim(24, 60)
ax2.set_ylim(50,600)
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.plot(x2, y2, lw=0.75, color = 'blue', label = '225')
ax2.tick_params(direction = 'inout', top = False, bottom = True, right = False, left = False)
ax2.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_2 = ax2.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_2.legendHandles:
    item.set_visible(False)
for text in leg_2.get_texts():
    text.set_color("blue")
    
ax3 = plt.subplot(gs[2])
x3 = Cu3PSe4_200_NN_01_07['2q']
y3 = Cu3PSe4_200_NN_01_07['Intensity']
ax3.set_xlim(24, 60)
ax3.set_ylim(100,9600)
#ax2.set_ylabel('Intensity (a.u.)')
ax3.set_xticklabels([])
ax3.set_yticklabels([])
ax3.plot(x3, y3, lw=0.75, color = 'purple', label = '200')
ax3.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax3.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_3 = ax3.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_3.legendHandles:
    item.set_visible(False)
for text in leg_3.get_texts():
    text.set_color("purple")
    
ax4 = plt.subplot(gs[3])
x4 = Cu3PSe4_150_NN_01_07['2q']
y4 = Cu3PSe4_150_NN_01_07['Intensity']
ax4.set_xlim(24, 60)
ax4.set_ylim(10,31000)
#ax2.set_ylabel('Intensity (a.u.)')
ax4.set_xticklabels([])
ax4.set_yticklabels([])
ax4.plot(x4, y4, lw=0.75, color = 'red', label = '150')
ax4.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax4.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_4 = ax4.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_4.legendHandles:
    item.set_visible(False)
for text in leg_4.get_texts():
    text.set_color("red")
    
ax5 = plt.subplot(gs[4])
x5 = Se_PDF['2q']
y5 = Se_PDF['Intensity']
ax5.set_xlim(24,60)
ax5.set_ylim(0,120)
#a2.set_ylabel('Intensity (a.u.)')
ax5.set_xticklabels([])
ax5.set_yticklabels([])
ax5.vlines(x5, [0], y5, color = 'k', label = 'Se PDF 00-042-1425')
ax5.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax5.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_5 = ax5.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_5.legendHandles:
    item.set_visible(False)
for text in leg_5.get_texts():
    text.set_color("black")
    
ax6 = plt.subplot(gs[5])
x6 = CuRSe_PDF['2q']
y6 = CuRSe_PDF['Intensity']
ax6.set_xlim(24,60)
ax6.set_ylim(10,1200)
#a2.set_ylabel('Intensity (a.u.)')
ax6.set_xticklabels([])
ax6.set_yticklabels([])
ax6.vlines(x6, [0], y6, color = 'orange', label = 'Cu$_{0.87}$Se PDF 01-089-2734')
ax6.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax6.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_6 = ax6.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_6.legendHandles:
    item.set_visible(False)
for text in leg_6.get_texts():
    text.set_color("orange")
    
ax7 = plt.subplot(gs[6])
x7 = Cu3PSe4_PDF['2q']
y7 = Cu3PSe4_PDF['Intensity']
ax7.set_xlim(24,60)
ax7.set_ylim(10,1750)
#ax2.set_ylabel('Intensity (a.u.)')
ax7.set_xticklabels([20,25,30,35,40,45,50,55,60], fontsize = 12)
ax7.set_yticklabels([])
ax7.vlines(x7, [0], y7, color = 'green', label = 'Cu$_3$PSe$_4$ PDF 04-006-8347')
ax7.tick_params(direction = 'inout', top = True, bottom = True, right = False, left = False)
ax7.legend(loc = legLoc, frameon = False, bbox_transform=plt.gcf().transFigure)

leg_7 = ax7.legend(handlelength=0, handletextpad=0, fancybox=False, frameon=False, fontsize=10)
for item in leg_7.legendHandles:
    item.set_visible(False)
for text in leg_7.get_texts():
    text.set_color("green")
    
#x = Se_PDF['2q']
#y = Se_PDF['Intensity']
#plt.bar(x,y,align='center', color='k', width=0.25)
#set_shared_ylabel('$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', 'Intensity (a.u.)')
fig.text(.5, 0.05, '$2\Theta$ ($^\circ$, CuK$_{\\alpha}$)', ha='center', va='center', fontsize = 12)
fig.text(0.1,.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical', fontsize = 12)
plt.savefig("Cu3PSe4_2020_01_29_NN-01-07.pdf", dpi=10000)
plt.show()
